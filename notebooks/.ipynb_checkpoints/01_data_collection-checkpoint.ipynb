# %%
import pandas as pd

# %%
companies = [
    # Oil Sector
    ["Reliance Industries", "RELIANCE", "Oil"],
    ["ONGC", "ONGC", "Oil"],
    ["IOC", "IOC", "Oil"],
    ["BPCL", "BPCL", "Oil"],

    # Gas / LPG Sector
    ["GAIL India", "GAIL", "Gas"],
    ["Petronet LNG", "PETRONET", "Gas"],
    ["Indraprastha Gas", "IGL", "Gas"],
    ["Gujarat Gas", "GUJGASLTD", "Gas"],

    # Banking
    ["HDFC Bank", "HDFCBANK", "Banking"],
    ["ICICI Bank", "ICICIBANK", "Banking"],
    ["State Bank of India", "SBIN", "Banking"],

    # IT
    ["TCS", "TCS", "IT"],
    ["Infosys", "INFY", "IT"],
    ["Wipro", "WIPRO", "IT"],

    # Defense
    ["HAL", "HAL", "Defense"],
    ["BEL", "BEL", "Defense"],

    # Infra
    ["Larsen & Toubro", "LT", "Infra"],
    ["KEC International", "KEC", "Infra"],

    # Auto
    ["Tata Motors", "TATAMOTORS", "Auto"],
    ["Maruti Suzuki", "MARUTI", "Auto"]
]

# %%
df_companies = pd.DataFrame(companies, columns=["Company", "Symbol", "Sector"])
df_companies.to_csv("companies.csv", index=False)
print("companies.csv created successfully!")
# Out:
# companies.csv created successfully!

# %%
import time
import requests
import pandas as pd
from datetime import datetime

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
